# %%
import pandas as pd

# %%
credits = pd.read_csv('tmdb_5000_credits.csv')
movies = pd.read_csv('tmdb_5000_movies.csv')

# %%
credits.shape
# Out:
# (4803, 4)

# %%
credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %%
credits[credits.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [movie_id, title, cast, crew]
# Index: []

# %%
movies.shape
# Out:
# (4803, 20)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
# preprocess for id
credits['id'] = credits['movie_id']
credits.drop('movie_id', axis=1, inplace=True)

credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   4803 non-null   object
#  1   cast    4803 non-null   object
#  2   crew    4803 non-null   object
#  3   id      4803 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %%
movies = movies.merge(credits, on='id')

movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
movies = movies[['id', 'original_title', 'overview',
                 'genres', 'keywords', 'popularity', 'cast', 'crew']]

# %%
movies.head(1)
# Out:
#       id original_title                                           overview  \
# 0  19995         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  popularity  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...  150.437577
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
movies.corr(numeric_only=True)
# Out:
#                   id  popularity
# id          1.000000    0.031202
# popularity  0.031202    1.000000

# %%
movies.isna().sum()
# Out:
# id                0
# original_title    0
# overview          3
# genres            0
# keywords          0
# popularity        0
# cast              0
# crew              0
# dtype: int64

# %%
movies.dropna(inplace=True)
# Out:
# /var/folders/84/k0t_2gx977vgp05hwmpt41400000gn/T/ipykernel_6539/3786870272.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies.dropna(inplace=True)

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies.iloc[0]
# Out:
# id                                                            19995
# original_title                                               Avatar
# overview          In the 22nd century, a paraplegic Marine is di...
# genres            [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# keywords          [{"id": 1463, "name": "culture clash"}, {"id":...
# popularity                                               150.437577
# cast              [{"cast_id": 242, "character": "Jake Sully", "...
# crew              [{"credit_id": "52fe48009251416c750aca23", "de...
# Name: 0, dtype: object

# %%
from ast import literal_eval

# %%
def extract_genres_and_keywords(obj):
    l = []
    for o in literal_eval(obj):
        l.append(o['name'])

    return l

# %%
movies['genres'] = movies['genres'].apply(extract_genres_and_keywords)
movies['keywords'] = movies['keywords'].apply(extract_genres_and_keywords)
# Out:
# /var/folders/84/k0t_2gx977vgp05hwmpt41400000gn/T/ipykernel_6539/557251948.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['genres'] = movies['genres'].apply(extract_genres_and_keywords)
# /var/folders/84/k0t_2gx977vgp05hwmpt41400000gn/T/ipykernel_6539/557251948.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['keywords'] = movies['keywords'].apply(extract_genres_and_keywords)

# %%
movies
# Out:
#           id                            original_title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# ...

# %%
def extract_first_three_cast_names(obj):
    return list(map(lambda cast: cast['name'], literal_eval(obj)[:3]))

# %%
movies['cast'] = movies['cast'].apply(extract_first_three_cast_names)
# Out:
# /var/folders/84/k0t_2gx977vgp05hwmpt41400000gn/T/ipykernel_6539/1841006582.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['cast'] = movies['cast'].apply(extract_first_three_cast_names)

# %%
movies
# Out:
#           id                            original_title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# ...

# %%
def extract_director_name(obj):
    filtered_director_crew = list(
        filter(lambda crew: crew['job'] == 'Director', literal_eval(obj)))
    return list(map(lambda item: item['name'], filtered_director_crew))


def replace_empty_space(obj):
    return [x.replace(" ", "") for x in obj]

# %%
movies['crew'] = movies['crew'].apply(extract_director_name)
# Out:
# /var/folders/84/k0t_2gx977vgp05hwmpt41400000gn/T/ipykernel_6539/823662402.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['crew'] = movies['crew'].apply(extract_director_name)

# %%
movies['overview'] = movies['overview'].apply(
    lambda sentence: sentence.split())
# Out:
# /var/folders/84/k0t_2gx977vgp05hwmpt41400000gn/T/ipykernel_6539/1992774069.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['overview'] = movies['overview'].apply(

# %%
movies
# Out:
#           id                            original_title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                                overview  \
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     [Captain, Barbossa,, long, believed, to, be, d...
# 2     [A, cryptic, message, from, Bond’s, past, send...
# 3     [Following, the, death, of, District, Attorney...
# ...

# %%
movies['genres'] = movies['genres'].apply(replace_empty_space)
movies['cast'] = movies['cast'].apply(replace_empty_space)
movies['cast'] = movies['cast'].apply(replace_empty_space)
movies['crew'] = movies['crew'].apply(replace_empty_space)
# Out:
# /var/folders/84/k0t_2gx977vgp05hwmpt41400000gn/T/ipykernel_6539/3344645441.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['genres'] = movies['genres'].apply(replace_empty_space)
# /var/folders/84/k0t_2gx977vgp05hwmpt41400000gn/T/ipykernel_6539/3344645441.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['cast'] = movies['cast'].apply(replace_empty_space)
# /var/folders/84/k0t_2gx977vgp05hwmpt41400000gn/T/ipykernel_6539/3344645441.py:3: SettingWithCopyWarning:
# ...

# %%
movies
# Out:
#           id                            original_title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                                overview  \
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     [Captain, Barbossa,, long, believed, to, be, d...
# 2     [A, cryptic, message, from, Bond’s, past, send...
# 3     [Following, the, death, of, District, Attorney...
# ...

# %%
movies['tags'] = movies['overview'] + movies['genres'] + \
    movies['keywords'] + movies['cast'] + movies['crew']
# Out:
# /var/folders/84/k0t_2gx977vgp05hwmpt41400000gn/T/ipykernel_6539/2360761068.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['tags'] = movies['overview'] + movies['genres'] + \

# %%
new_movies = movies.drop(
    ['overview', 'genres', 'keywords', 'cast', 'crew'], axis=1)

# %%
new_movies['tags'] = new_movies['tags'].apply(
    lambda item: " ".join(item)).apply(lambda item: item.lower())

# %%
new_movies['tags']
# Out:
# 0       in the 22nd century, a paraplegic marine is di...
# 1       captain barbossa, long believed to be dead, ha...
# 2       a cryptic message from bond’s past sends him o...
# 3       following the death of district attorney harve...
# 4       john carter is a war-weary, former military ca...
#                               ...
# 4798    el mariachi just wants to play his guitar and ...
# 4799    a newlywed couple's honeymoon is upended by th...
# 4800    "signed, sealed, delivered" introduces a dedic...
# 4801    when ambitious new york attorney sam is sent t...
# 4802    ever since the second grade when he first saw ...
# Name: tags, Length: 4800, dtype: object

# %%
new_movies[new_movies['original_title'] == 'Batman']
# Out:
#         id original_title  popularity  \
# 1359   268         Batman   44.104469
# 4267  2661         Batman    9.815394
#
#                                                    tags
# 1359  the dark knight of gotham city begins his war ...
# 4267  the dynamic duo faces four super-villains who ...

# %%
# Implement steming on similar words

from nltk.stem.porter import PorterStemmer

ps = PorterStemmer()


def stem_similar_strings(sentence):
    all_words = sentence.split()
    stem_words = list(map(lambda each_string: ps.stem(each_string), all_words))
    return " ".join(stem_words)

# %%
new_movies['tags'] = new_movies['tags'].apply(stem_similar_strings)

# %%
new_movies['tags'][0]
# Out:
# 'in the 22nd century, a parapleg marin is dispatch to the moon pandora on a uniqu mission, but becom torn between follow order and protect an alien civilization. action adventur fantasi sciencefict cultur clash futur space war space coloni societi space travel futurist romanc space alien tribe alien planet cgi marin soldier battl love affair anti war power relat mind and soul 3d samworthington zoesaldana sigourneyweav jamescameron'

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(max_features=5000, stop_words='english')

movie_vector = cv.fit_transform(new_movies['tags']).toarray()

# %%
cv.get_feature_names_out()
# Out:
# array(['000', '007', '10', ..., 'zone', 'zoo', 'zooeydeschanel'],
#       shape=(5000,), dtype=object)

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(movie_vector)

# %%
similarity[2]
# Out:
# array([0.03563483, 0.04600437, 1.        , ..., 0.02174427, 0.        ,
#        0.        ], shape=(4800,))

# %%
new_movies[new_movies['original_title'] == 'Batman Begins']
# Out:
#       id original_title  popularity  \
# 119  272  Batman Begins  115.040024
#
#                                                   tags
# 119  driven by tragedy, billionaire bruce wayne ded...

# %%
movie_index = new_movies[new_movies['original_title']== 'Batman'].index[0]
distances = similarity[movie_index]

# %%
distances
# Out:
# array([0.07126966, 0.11501093, 0.06666667, ..., 0.        , 0.        ,
#        0.        ], shape=(4800,))

# %%
def recommend(movie_title):
    # get index of searched movie
    movie_index = new_movies[new_movies['original_title']== movie_title].index[0]
    # get distances of current movie from similarities
    distances = similarity[movie_index]
    recommendation = []
    for distance in sorted(list(enumerate(distances)), reverse=True, key=lambda x:x[1])[1:6]:
        index = distance[0]
        recommendation.append(new_movies.iloc[index]['original_title'])
    return recommendation

# %%
recommend('Batman Begins')
# Out:
# ['The Dark Knight',
#  'Batman',
#  'The Dark Knight Rises',
#  'Batman & Robin',
#  'Kick-Ass']

# %%
import joblib
joblib.dump(model, 'model.pkl')
